# %% [markdown]
# # My Data Science Journey: Tools and Techniques

# %% [markdown]
# ## Introduction
# This notebook provides an overview of the essential tools, languages, and libraries used in data science. It serves as a comprehensive guide for anyone beginning their journey in data science, covering the fundamental building blocks of the field including programming languages, popular libraries, and development tools.

# %% [markdown]
# ## Data Science Languages
#
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Java
# 6. C++
# 7. JavaScript
# 8. Julia

# %% [markdown]
# ## Data Science Libraries
#
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-learn
# 6. Keras
# 7. TensorFlow
# 8. PyTorch
# 9. Apache Spark
# 10. Vegas

# %% [markdown]
# ## Data Science Tools
#
# | Data Science Tools |
# |---------------------|
# | Jupyter Notebook    |
# | RStudio            |
# | Apache Spark       |
# | TensorFlow         |
# | Apache Hadoop      |
# | Tableau            |
# | Power BI           |
# | Excel              |
# | KNIME              |
# | Apache Airflow     |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours")
# Out:
# 200 minutes is equal to 3.3333333333333335 hours

# %% [markdown]
# ## Objectives:
#
# - List popular languages for Data Science
# - List commonly used libraries for Data Science
# - List popular tools for Data Science
# - Create arithmetic expressions
# - Convert units of measurement

# %% [markdown]
# ## Author
#
# Mohamadmehdi Moayeri
